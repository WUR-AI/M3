# %%
import datamart_profiler
import pandas as pd
from pathlib import Path

# Walk up from cwd until we find the repo data folder (works from any notebook subdir)
BASE = Path.cwd().resolve()
for candidate in [BASE, *BASE.parents]:
    csv_path = candidate / "data" / "biota_dataset" / "samples.csv"
    if csv_path.exists():
        BASE = candidate
        break
else:
    raise FileNotFoundError(
        "Could not find data/biota_dataset/biota.csv. "
        "Expected it under the metadata_agent repo root."
    )

data_frame = pd.read_csv(csv_path)
metadata = datamart_profiler.process_dataset(data_frame)
# Out:
# /home/com3dian/miniconda3/envs/sam2/lib/python3.12/site-packages/datamart_profiler/core.py:199: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   data = data.astype(object).fillna('').astype(str)

# %%
metadata
# Out:
# {'nb_rows': 51851,
#  'nb_profiled_rows': 51851,
#  'nb_columns': 11,
#  'columns': [{'name': 'sample_id',
#    'structural_type': 'http://schema.org/Integer',
#    'semantic_types': ['http://schema.org/identifier'],
#    'unclean_values_ratio': 0.0,
#    'num_distinct_values': 51851,
#    'mean': 88552.26996586373,
#    'stddev': 41277.065647465315,
#    'coverage': [{'range': {'gte': 35447.0, 'lte': 70807.0}},
#     {'range': {'gte': 106463.0, 'lte': 126869.0}},
#     {'range': {'gte': 128578.0, 'lte': 150159.0}}]},
#   {'name': 'sampling_station_id',
#    'structural_type': 'http://schema.org/Integer',
#    'semantic_types': ['http://schema.org/identifier'],
#    'unclean_values_ratio': 0.0,
#    'num_distinct_values': 5107,
#    'mean': 2861.7893001099305,
#    'stddev': 2360.716361200522,
#    'coverage': [{'range': {'gte': 146.0, 'lte': 2669.0}},
#     {'range': {'gte': 2905.0, 'lte': 6673.0}}]},
#   {'name': 'sampling_type',
#    'structural_type': 'http://schema.org/Text',
#    'semantic_types': ['http://schema.org/Enumeration'],
#    'num_distinct_values': 2},
#   {'name': 'date',
#    'structural_type': 'http://schema.org/Text',
#    'semantic_types': ['http://schema.org/Enumeration',
#     'http://schema.org/DateTime'],
#    'num_distinct_values': 505},
#   {'name': 'platform',
#    'structural_type': 'http://schema.org/Text',
#    'semantic_types': ['http://schema.org/Enumeration'],
#    'num_distinct_values': 2},
#   {'name': 'tidal_basin_name',
#    'structural_type': 'http://schema.org/Text',
#    'semantic_types': ['http://schema.org/Enumeration'],
#    'num_distinct_values': 12},
#   {'name': 'tidal_flat_name',
#    'structural_type': 'http://schema.org/Text',
#    'semantic_types': ['http://schema.org/Enumeration'],
#    'missing_values_ratio': 0.0002507184046595051,
#    'num_distinct_values': 41},
#   {'name': 'x',
#    'structural_type': 'http://schema.org/Float',
#    'semantic_types': [],
#    'unclean_values_ratio': 0.0,
#    'mean': 5.69659050986474,
#    'stddev': 0.641438756636991,
#    'coverage': [{'range': {'gte': 4.863833, 'lte': 5.384167}},
#     {'range': {'gte': 5.4385, 'lte': 6.059833}},
#     {'range': {'gte': 6.207333, 'lte': 7.186}}]},
#   {'name': 'y',
#    'structural_type': 'http://schema.org/Float',
#    'semantic_types': [],
#    'unclean_values_ratio': 0.0,
#    'mean': 53.30305328933032,
#    'stddev': 0.15172093422403582,
#    'coverage': [{'range': {'gte': 53.1255, 'lte': 53.311333}},
#     {'range': {'gte': 53.3385, 'lte': 53.506167}}]},
#   {'name': 'median_grain_size',
#    'structural_type': 'http://schema.org/Float',
#    'semantic_types': [],
#    'unclean_values_ratio': 0.0,
#    'missing_values_ratio': 0.0706833040828528,
#    'mean': 151.15877576474406,
#    'stddev': 44.206219638524956,
#    'coverage': [{'range': {'gte': 37.86, 'lte': 116.7}},
#     {'range': {'gte': 124.1, 'lte': 172.9}},
#     {'range': {'gte': 176.8, 'lte': 241.3}}]},
#   {'name': 'percentage_mud',
#    'structural_type': 'http://schema.org/Float',
#    'semantic_types': [],
#    'unclean_values_ratio': 0.0,
#    'missing_values_ratio': 0.0706833040828528,
#    'mean': 13.872440127837994,
#    'stddev': 15.370499256472618,
#    'coverage': [{'range': {'gte': 1.61, 'lte': 12.9}},
#     {'range': {'gte': 16.4, 'lte': 36.7}}]}],
#  'nb_temporal_columns': 1,
#  'nb_categorical_columns': 4,
#  'nb_numerical_columns': 6,
#  'types': ['categorical', 'numerical', 'temporal'],
#  'temporal_coverage': [{'type': 'datetime',
#    'column_names': ['date'],
#    'column_indexes': [3],
#    'column_types': ['http://schema.org/DateTime'],
#    'ranges': [{'range': {'gte': 1217376000.0, 'lte': 1342742400.0}},
#     {'range': {'gte': 1373846400.0, 'lte': 1502150400.0}},
#     {'range': {'gte': 1532044800.0, 'lte': 1631491200.0}}],
#    'temporal_resolution': 'day'}],
#  'attribute_keywords': ['sample_id',
#   'sample',
#   'id',
#   'sampling_station_id',
#   'sampling',
#   'station',
#   'id',
#   'sampling_type',
#   'sampling',
#   'type',
#   'date',
#   'platform',
#   'tidal_basin_name',
#   'tidal',
#   'basin',
#   'name',
#   'tidal_flat_name',
#   'tidal',
#   'flat',
#   'name',
#   'x',
#   'y',
#   'median_grain_size',
#   'median',
#   'grain',
#   'size',
#   'percentage_mud',
#   'percentage',
#   'mud']}
